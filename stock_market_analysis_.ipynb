# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaya9yellow/dvs-stock-market-analysis-/blob/main/stock_market_analysis_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
dts=pd.read_csv(r"/content/NESTLEIND.csv")
dts
# Out:
#             Date     Symbol Series  ...   Trades  Deliverable Volume  %Deliverble
# 0     2010-01-08  NESTLEIND     EQ  ...      NaN                 438       0.6759
# 1     2010-01-11  NESTLEIND     EQ  ...      NaN                 638       0.7733
# 2     2010-01-12  NESTLEIND     EQ  ...      NaN               67695       0.9905
# 3     2010-01-13  NESTLEIND     EQ  ...      NaN                 718       0.6957
# 4     2010-01-14  NESTLEIND     EQ  ...      NaN              329193       0.9965
# ...          ...        ...    ...  ...      ...                 ...          ...
# 2801  2021-04-26  NESTLEIND     EQ  ...  14294.0              117593       0.7718
# 2802  2021-04-27  NESTLEIND     EQ  ...  14171.0               21944       0.4915
# 2803  2021-04-28  NESTLEIND     EQ  ...  18998.0               54382       0.6260
# 2804  2021-04-29  NESTLEIND     EQ  ...  19768.0               40477       0.5047
# ...

# %%
dts.head(10)
# Out:
#          Date     Symbol Series  ...  Trades  Deliverable Volume  %Deliverble
# 0  2010-01-08  NESTLEIND     EQ  ...     NaN                 438       0.6759
# 1  2010-01-11  NESTLEIND     EQ  ...     NaN                 638       0.7733
# 2  2010-01-12  NESTLEIND     EQ  ...     NaN               67695       0.9905
# 3  2010-01-13  NESTLEIND     EQ  ...     NaN                 718       0.6957
# 4  2010-01-14  NESTLEIND     EQ  ...     NaN              329193       0.9965
# 5  2010-01-15  NESTLEIND     EQ  ...     NaN                7303       0.8875
# 6  2010-01-18  NESTLEIND     EQ  ...     NaN                 689       0.7803
# 7  2010-01-19  NESTLEIND     EQ  ...     NaN                 432       0.6279
# 8  2010-01-20  NESTLEIND     EQ  ...     NaN                 549       0.8565
# 9  2010-01-21  NESTLEIND     EQ  ...     NaN                 623       0.7497
#
# [10 rows x 15 columns]

# %%
dts.tail(6)
# Out:
#             Date     Symbol Series  ...   Trades  Deliverable Volume  %Deliverble
# 2800  2021-04-23  NESTLEIND     EQ  ...  18481.0               27117       0.3953
# 2801  2021-04-26  NESTLEIND     EQ  ...  14294.0              117593       0.7718
# 2802  2021-04-27  NESTLEIND     EQ  ...  14171.0               21944       0.4915
# 2803  2021-04-28  NESTLEIND     EQ  ...  18998.0               54382       0.6260
# 2804  2021-04-29  NESTLEIND     EQ  ...  19768.0               40477       0.5047
# 2805  2021-04-30  NESTLEIND     EQ  ...  24063.0               54977       0.5622
#
# [6 rows x 15 columns]

# %%
dts.shape
# Out:
# (2806, 15)

# %%
dts.size
# Out:
# 42090

# %%
dts.keys()
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
dts.isnull()
# Out:
#        Date  Symbol  Series  ...  Trades  Deliverable Volume  %Deliverble
# 0     False   False   False  ...    True               False        False
# 1     False   False   False  ...    True               False        False
# 2     False   False   False  ...    True               False        False
# 3     False   False   False  ...    True               False        False
# 4     False   False   False  ...    True               False        False
# ...     ...     ...     ...  ...     ...                 ...          ...
# 2801  False   False   False  ...   False               False        False
# 2802  False   False   False  ...   False               False        False
# 2803  False   False   False  ...   False               False        False
# 2804  False   False   False  ...   False               False        False
# 2805  False   False   False  ...   False               False        False
#
# [2806 rows x 15 columns]

# %%
dts.describe()
# Out:
#          Prev Close          Open  ...  Deliverable Volume  %Deliverble
# count   2806.000000   2806.000000  ...         2806.000000  2806.000000
# mean    7507.122933   7518.226960  ...        33574.361725     0.662074
# std     4180.468727   4189.232067  ...        45266.246683     0.162609
# min     2489.350000   2295.000000  ...           32.000000     0.131000
# 25%     4641.150000   4650.000000  ...        10789.500000     0.548025
# 50%     6120.975000   6118.275000  ...        22019.000000     0.665350
# 75%     9678.700000   9697.500000  ...        41911.500000     0.783675
# max    18732.700000  18844.000000  ...       929598.000000     0.996500
#
# [8 rows x 12 columns]

# %%
dts.dtypes
# Out:
# Date                   object
# Symbol                 object
# Series                 object
# Prev Close            float64
# Open                  float64
# High                  float64
# Low                   float64
# Last                  float64
# Close                 float64
# VWAP                  float64
# Volume                  int64
# Turnover              float64
# Trades                float64
# Deliverable Volume      int64
# %Deliverble           float64
# dtype: object

# %%
dts.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2801    False
# 2802    False
# 2803    False
# 2804    False
# 2805    False
# Length: 2806, dtype: bool

# %%
  dts.drop_duplicates()
# Out:
# <bound method DataFrame.drop_duplicates of             Date     Symbol Series  ...   Trades  Deliverable Volume  %Deliverble
# 0     2010-01-08  NESTLEIND     EQ  ...      NaN                 438       0.6759
# 1     2010-01-11  NESTLEIND     EQ  ...      NaN                 638       0.7733
# 2     2010-01-12  NESTLEIND     EQ  ...      NaN               67695       0.9905
# 3     2010-01-13  NESTLEIND     EQ  ...      NaN                 718       0.6957
# 4     2010-01-14  NESTLEIND     EQ  ...      NaN              329193       0.9965
# ...          ...        ...    ...  ...      ...                 ...          ...
# 2801  2021-04-26  NESTLEIND     EQ  ...  14294.0              117593       0.7718
# 2802  2021-04-27  NESTLEIND     EQ  ...  14171.0               21944       0.4915
# 2803  2021-04-28  NESTLEIND     EQ  ...  18998.0               54382       0.6260
# 2804  2021-04-29  NESTLEIND     EQ  ...  19768.0               40477       0.5047
# ...

# %%
dts.mean()
# Out:
# Prev Close            7.507123e+03
# Open                  7.518227e+03
# High                  7.604765e+03
# Low                   7.425280e+03
# Last                  7.511272e+03
# Close                 7.512040e+03
# VWAP                  7.514319e+03
# Volume                5.449900e+04
# Turnover              5.493844e+13
# Trades                1.104331e+04
# Deliverable Volume    3.357436e+04
# %Deliverble           6.620741e-01
# dtype: float64

# %%
dts.median()
# Out:
# Prev Close            6.120975e+03
# Open                  6.118275e+03
# High                  6.200000e+03
# Low                   6.036000e+03
# Last                  6.117050e+03
# Close                 6.122550e+03
# VWAP                  6.124270e+03
# Volume                3.285500e+04
# Turnover              1.942007e+13
# Trades                6.352000e+03
# Deliverable Volume    2.201900e+04
# %Deliverble           6.653500e-01
# dtype: float64

# %%
dts.mode()
# Out:
#             Date     Symbol Series  ...  Trades  Deliverable Volume  %Deliverble
# 0     2010-01-08  NESTLEIND     EQ  ...  1780.0              8139.0       0.5185
# 1     2010-01-11        NaN    NaN  ...  2987.0             18899.0       0.6334
# 2     2010-01-12        NaN    NaN  ...  4065.0                 NaN       0.6410
# 3     2010-01-13        NaN    NaN  ...  4234.0                 NaN       0.6512
# 4     2010-01-14        NaN    NaN  ...  4359.0                 NaN       0.6592
# ...          ...        ...    ...  ...     ...                 ...          ...
# 2801  2021-04-26        NaN    NaN  ...     NaN                 NaN          NaN
# 2802  2021-04-27        NaN    NaN  ...     NaN                 NaN          NaN
# 2803  2021-04-28        NaN    NaN  ...     NaN                 NaN          NaN
# 2804  2021-04-29        NaN    NaN  ...     NaN                 NaN          NaN
# 2805  2021-04-30        NaN    NaN  ...     NaN                 NaN          NaN
#
# ...

# %%
np.var(dts)
# Out:
# Prev Close            1.747009e+07
# Open                  1.754341e+07
# High                  1.792122e+07
# Low                   1.707643e+07
# Last                  1.748499e+07
# Close                 1.748879e+07
# VWAP                  1.749006e+07
# Volume                4.794660e+09
# Turnover              9.124820e+27
# Trades                1.538420e+08
# Deliverable Volume    2.048303e+09
# %Deliverble           2.643219e-02
# dtype: float64

# %%
np.std(dts)
# Out:
# Prev Close            4.179724e+03
# Open                  4.188486e+03
# High                  4.233346e+03
# Low                   4.132364e+03
# Last                  4.181506e+03
# Close                 4.181960e+03
# VWAP                  4.182112e+03
# Volume                6.924349e+04
# Turnover              9.552392e+13
# Trades                1.240330e+04
# Deliverable Volume    4.525818e+04
# %Deliverble           1.625798e-01
# dtype: float64

# %%
dts.head()
# Out:
#          Date     Symbol Series  ...  Trades  Deliverable Volume  %Deliverble
# 0  2010-01-08  NESTLEIND     EQ  ...     NaN                 438       0.6759
# 1  2010-01-11  NESTLEIND     EQ  ...     NaN                 638       0.7733
# 2  2010-01-12  NESTLEIND     EQ  ...     NaN               67695       0.9905
# 3  2010-01-13  NESTLEIND     EQ  ...     NaN                 718       0.6957
# 4  2010-01-14  NESTLEIND     EQ  ...     NaN              329193       0.9965
#
# [5 rows x 15 columns]

# %%
#example of range for one column
df['Open'].max() - df['Open'].min()

# %%
#example of quantile for one column
dts['Open'].quantile([.25,.5,.75])
# Out:
# 0.25    4650.000
# 0.50    6118.275
# 0.75    9697.500
# Name: Open, dtype: float64

# %%
dts.skew()
# Out:
# Prev Close            1.206407
# Open                  1.206521
# High                  1.206577
# Low                   1.204678
# Last                  1.204077
# Close                 1.204876
# VWAP                  1.204424
# Volume                5.138128
# Turnover              6.105883
# Trades                2.772700
# Deliverable Volume    8.325159
# %Deliverble          -0.194273
# dtype: float64

# %%
dts.kurtosis()
# Out:
# Prev Close              0.308458
# Open                    0.308704
# High                    0.303387
# Low                     0.307559
# Last                    0.298096
# Close                   0.301979
# VWAP                    0.300990
# Volume                 47.482410
# Turnover               78.776427
# Trades                 11.360954
# Deliverable Volume    119.547519
# %Deliverble            -0.486616
# dtype: float64

# %%
import matplotlib.pyplot
dts.boxplot()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
dts.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2bfd3c5e50>,
# ...
#       dtype=object)
